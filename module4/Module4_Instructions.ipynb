# %% [markdown]
# # Module 4 Extra Instruction
#
# We were not able to clone git repo from GitLab to Nautlus JupyterHub. Therefore, we prepared another routine. Please, follow thes steps.

# %% [markdown]
# ## Steps
#
# 1. Go to https://gp-engine.nrp-nautilus.io/
# 2. Open a terminal.
# 3. clone the module4 repo from the terminal using following command.
#
# ```bash
# git clone https://github.com/skhanbd4/cloud_comp.git
# ```
# 4. Navigate to the `module4` folder inside the `cloud_comp` directory.
#
# 5. Open the schedule file and begin working on the labs, practices, and exercise.
#
# **Note:** You have already completed **Lab 4.1**. If not, please finish it first. We will **skip Lab 4.2**.
# So, complete **Lab 4.3**, **Practice 4.1**, and **Exercise 4.1**.
# Follow the instructions within each assignment to learn how to submit your outputs for full credit.
